# %% [markdown]
# # **Apple AppStore Data**
# **Complete Exploratory Data Analysis**

# %% [markdown]
# Author: **Hasnain Zaman**\
# Contact Info:\
# [Email](hasnainzaman7860@gmail.com)\
# [Github](https://github.com/HasnainZaman)\
# [Linkedin](https://www.linkedin.com/in/hasnainzaman)

# %% [markdown]
# ## About Data
# - Data: Apple AppStore
# - Data Age: The data was collected in the month of October 2021.
# - **Dataset:** 🔗 [*link*](https://www.kaggle.com/datasets/gauthamp10/apple-appstore-apps)
#
# ## **Content:**
# This data is about the Apps on Apple Play Store. It provide information about the Apps like App_Name, Primary_Genre in which they are launched and their target audience age_groups. Moreover, it provide information about the Developers of the Apps, their Reviews, Average User Rating , Size of the Apps in Bytes and Price of the Apps. This data frame originally consists of 21 coumns and 1230375 rows.

# %% [markdown]
# ### Import libraries

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load data

# %%
# load the data
df =pd.read_csv("appleAppData.csv")

# %% [markdown]
# ## Preprocessing

# %%
df.head()
# Out:
#                              App_Id                 App_Name  \
# 0               com.hkbu.arc.apaper           A+ Paper Guide
# 1               com.dmitriev.abooks                  A-Books
# 2                    no.terp.abooks                  A-books
# 3          fr.antoinettefleur.Book1              A-F Book #1
# 4  com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4  https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0             4+  21993472.0                  8.0  2017-09-28T03:02:41Z
# ...

# %%
df.shape
# Out:
# (1230376, 21)

# %%
print(f"The number of rows are {df.shape[0]} and the number of columns are {df.shape[1]}")
# Out:
# The number of rows are 1230376 and the number of columns are 21

# %% [markdown]
# ### Checking column Names

# %%
df.columns
# Out:
# Index(['App_Id', 'App_Name', 'AppStore_Url', 'Primary_Genre', 'Content_Rating',
#        'Size_Bytes', 'Required_IOS_Version', 'Released', 'Updated', 'Version',
#        'Price', 'Currency', 'Free', 'DeveloperId', 'Developer',
#        'Developer_Url', 'Developer_Website', 'Average_User_Rating', 'Reviews',
#        'Current_Version_Score', 'Current_Version_Reviews'],
#       dtype='object')

# %%
# data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230376 entries, 0 to 1230375
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   App_Id                   1230376 non-null  object
#  1   App_Name                 1230375 non-null  object
#  2   AppStore_Url             1230376 non-null  object
#  3   Primary_Genre            1230376 non-null  object
#  4   Content_Rating           1230376 non-null  object
#  5   Size_Bytes               1230152 non-null  float64
#  6   Required_IOS_Version     1230376 non-null  object
#  7   Released                 1230373 non-null  object
#  8   Updated                  1230376 non-null  object
#  9   Version                  1230376 non-null  object
#  10  Price                    1229886 non-null  float64
#  11  Currency                 1230376 non-null  object
#  12  Free                     1230376 non-null  bool
# ...

# %% [markdown]
# ### Descriptie Statistics

# %%
df.describe()
# Out:
#          Size_Bytes         Price   DeveloperId  Average_User_Rating  \
# count  1.230152e+06  1.229886e+06  1.230376e+06         1.230376e+06
# mean   7.510857e+07  5.041264e-01  1.092869e+09         1.788387e+00
# std    2.318726e+08  6.869674e+00  4.090897e+08         2.154105e+00
# min    2.762800e+04  0.000000e+00  2.816565e+08         0.000000e+00
# 25%    2.041344e+07  0.000000e+00  7.381109e+08         0.000000e+00
# 50%    4.333158e+07  0.000000e+00  1.179711e+09         0.000000e+00
# 75%    8.365466e+07  0.000000e+00  1.471960e+09         4.333330e+00
# max    7.677945e+10  9.999900e+02  1.590233e+09         5.000000e+00
#
#             Reviews  Current_Version_Score  Current_Version_Reviews
# count  1.230376e+06           1.230376e+06             1.230376e+06
# mean   8.259478e+02           1.788387e+00             8.259478e+02
# std    5.016051e+04           2.154105e+00             5.016051e+04
# min    0.000000e+00           0.000000e+00             0.000000e+00
# ...

# %% [markdown]
# ### check Missing Values

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Developer_Website          643988
# Developer_Url                1109
# Price                         490
# Size_Bytes                    224
# Released                        3
# App_Name                        1
# Free                            0
# Current_Version_Score           0
# Reviews                         0
# Average_User_Rating             0
# Developer                       0
# DeveloperId                     0
# App_Id                          0
# Currency                        0
# Version                         0
# Updated                         0
# Required_IOS_Version            0
# Content_Rating                  0
# Primary_Genre                   0
# AppStore_Url                    0
# Current_Version_Reviews         0
# dtype: int64

# %%
# percentage of missing values
df.isnull().sum()/len(df)*100
# Out:
# App_Id                      0.000000
# App_Name                    0.000081
# AppStore_Url                0.000000
# Primary_Genre               0.000000
# Content_Rating              0.000000
# Size_Bytes                  0.018206
# Required_IOS_Version        0.000000
# Released                    0.000244
# Updated                     0.000000
# Version                     0.000000
# Price                       0.039825
# Currency                    0.000000
# Free                        0.000000
# DeveloperId                 0.000000
# Developer                   0.000000
# Developer_Url               0.090135
# Developer_Website          52.340748
# Average_User_Rating         0.000000
# Reviews                     0.000000
# Current_Version_Score       0.000000
# Current_Version_Reviews     0.000000
# dtype: float64

# %% [markdown]
# ### plot the missing values

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### Handling Null Values

# %% [markdown]
# `Developer_Website `         `643988`\
# `Developer_Url `               `1109`\
# `Price `                        `490`\
# `Size_Bytes `                  ` 224`\
# `Released`                        `3`\
# `App_Name`                        `1`

# %%
# drop developer website
df.drop("Developer_Website",axis=1,inplace=True)

# %%
# drop missing values
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (1228776, 20)

# %%
# now print the shape of the data
print(f"After dropping the missing values, the number of rows are {df.shape[0]} and the number of columns are {df.shape[1]}")
# Out:
# After dropping the missing values, the number of rows are 1228776 and the number of columns are 20

# %% [markdown]
# ### Duplicate Values

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1228776, 20)

# %%
print(f'After dropping the duplicates, the number of rows are {df.shape[0]} and the number of columns are {df.shape[1]}')
# Out:
# After dropping the duplicates, the number of rows are 1228776 and the number of columns are 20

# %%
# check the distribution of each numerical column
for i in df.columns:
    if df[i].dtype == 'int64' or df[i].dtype == 'float64':
        sns.distplot(df[i])
        plt.show()

# %% [markdown]
# ## Insights From Data

# %%
# unique primary genres
unique_genres = df['Primary_Genre'].unique()
print("Unique primary genres of apps:", unique_genres)
# Out:
# Unique primary genres of apps: ['Education' 'Book' 'Reference' 'News' 'Lifestyle' 'Health & Fitness'
#  'Games' 'Medical' 'Food & Drink' 'Sports' 'Shopping' 'Entertainment'
#  'Utilities' 'Stickers' 'Productivity' 'Music' 'Photo & Video' 'Travel'
#  'Business' 'Social Networking' 'Magazines & Newspapers' 'Navigation'
#  'Finance' 'Weather' 'Graphics & Design' 'Developer Tools']

# %%
# average user rating
avg_user_rating = df['Average_User_Rating'].mean()
print("Average user rating of apps:", avg_user_rating)
# Out:
# Average user rating of apps: 1.7890877375453296

# %%
# most reviewed app and how many reviews does it have
most_reviewed_app = df.loc[df['Reviews'].idxmax()]
print("Most reviewed app:", most_reviewed_app['App_Name'])
print("Number of reviews:", most_reviewed_app['Reviews'])
# Out:
# Most reviewed app: YouTube: Watch, Listen, Stream
# Number of reviews: 22685334

# %%
# average size of apps
avg_size_bytes = df['Size_Bytes'].mean()
print("Average size of apps (in bytes):", avg_size_bytes)
# Out:
# Average size of apps (in bytes): 75064153.85827035

# %%
# number of free and paid apps
num_free_apps = df[df['Free'] == True].shape[0]
num_paid_apps = df[df['Free'] == False].shape[0]
print("Number of free apps:", num_free_apps)
print("Number of paid apps:", num_paid_apps)
# Out:
# Number of free apps: 1126288
# Number of paid apps: 102488

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Free', data=df, palette='Set2')
plt.title('Count of Free vs. Paid Apps')
plt.xlabel('Type')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['Paid', 'Free'])
plt.show()

# %%
unique_content_ratings = df['Content_Rating'].unique()
print("Unique content ratings:", unique_content_ratings)
# Out:
# Unique content ratings: ['4+' '17+' '9+' '12+' 'Not yet rated']

# %%
# top 5 developers
top_developers = df['Developer'].value_counts().head(5)
print("Top 5 developers by number of apps:")
print(top_developers)
# Out:
# Top 5 developers by number of apps:
# Developer
# ChowNow                   3966
# Touch2Success             1649
# Alexander Velimirovic     1506
# MINDBODY, Incorporated    1247
# Phorest                   1131
# Name: count, dtype: int64

# %%
# plot the top 5 developers
sns.barplot(x=top_developers.index, y=top_developers)
plt.title("Top 5 Developers by Number of Apps")
plt.xlabel("Developer")
plt.ylabel("Number of Apps")
plt.xticks(rotation=45)
plt.show()

# %%
# most recent release date
most_recent_release = df['Released'].max()
print("Most recent release date:", most_recent_release)
# Out:
# Most recent release date: 2021-10-14T07:00:00Z

# %%
# average price of paid apps
avg_price_paid_apps = df[df['Free'] == False]['Price'].mean()
print("Average price of paid apps:", avg_price_paid_apps)
# Out:
# Average price of paid apps: 6.049236203262822

# %%
# most common required iOS version
most_common_ios_version = df['Required_IOS_Version'].mode()[0]
print("Most common required iOS version:", most_common_ios_version)
# Out:
# Most common required iOS version: 11.0

# %%
# distribution of app sizes across different content ratings
size_distribution_by_rating = df.groupby('Content_Rating')['Size_Bytes'].describe()
print("Distribution of app sizes across different content ratings:")
print(size_distribution_by_rating)
# Out:
# Distribution of app sizes across different content ratings:
#                    count          mean           std       min          25%  \
# Content_Rating
# 12+              89381.0  1.125725e+08  4.377546e+08  191073.0  27774976.00
# 17+             123966.0  7.931147e+07  4.465833e+08  158281.0  22926592.00
# 4+              979834.0  6.844622e+07  1.469187e+08   27628.0  19225219.25
# 9+               35585.0  1.482953e+08  2.765407e+08   33879.0  34743296.00
# Not yet rated       10.0  2.421888e+07  5.136964e+07   86305.0    277180.75
#
#                        50%          75%           max
# Content_Rating
# 12+             58593280.0  109723648.0  5.868532e+10
# 17+             48695296.0   86140928.0  7.677945e+10
# 4+              40751104.0   79152128.0  4.483795e+10
# 9+              72834048.0  154834944.0  1.263210e+10
# Not yet rated    1004712.5   15224670.0  1.610496e+08

# %%
# plot the distribution of app sizes across different content ratings
sns.boxplot(x='Content_Rating', y='Size_Bytes', data=df)
plt.title("Distribution of App Sizes Across Different Content Ratings")
plt.xlabel("Content Rating")
plt.ylabel("Size (in bytes)")
plt.xticks(rotation=45)
plt.show()

# %%
# ratio of free to paid apps by primary genre
ratio_free_to_paid_by_genre = df.groupby('Primary_Genre')['Free'].value_counts(normalize=True).unstack().fillna(0)
print("Ratio of free to paid apps by primary genre:")
print(ratio_free_to_paid_by_genre)
# Out:
# Ratio of free to paid apps by primary genre:
# Free                       False     True
# Primary_Genre
# Book                    0.136304  0.863696
# Business                0.021521  0.978479
# Developer Tools         0.395994  0.604006
# Education               0.145817  0.854183
# Entertainment           0.076933  0.923067
# Finance                 0.035013  0.964987
# Food & Drink            0.012058  0.987942
# Games                   0.082381  0.917619
# Graphics & Design       0.402448  0.597552
# Health & Fitness        0.055789  0.944211
# Lifestyle               0.038667  0.961333
# Magazines & Newspapers  0.003089  0.996911
# Medical                 0.088265  0.911735
# Music                   0.179500  0.820500
# Navigation              0.120111  0.879889
# News                    0.011858  0.988142
# Photo & Video           0.187240  0.812760
# Productivity            0.100987  0.899013
# Reference               0.180738  0.819262
# ...

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Reviews', y='Average_User_Rating', data=df, alpha=0.5)
plt.title('Average User Rating vs. Number of Reviews')
plt.xlabel('Number of Reviews')
plt.ylabel('Average User Rating')
plt.show()

# %%
# histogram of app sizes
plt.figure(figsize=(10, 6))
sns.histplot(df['Size_Bytes'], bins=20, kde=True)
plt.title('Histogram of App Sizes')
plt.xlabel('Size (Bytes)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # **Conclusion & Findings:**
# The primary goal of this to analyze the Apple Apps Store dataset and identify insights based on the data. During this EDA exercise, we have achieved several milestones:
# - The number of rows are `1230376` and the number of columns are `21`.
# - Missing value
#     - `Developer_Website  643988`\
# `Developer_Url    1109`\
# `Price        490`\
# `Size_Bytes  224`\
# `Released    3`\
# `App_Name    1`
# - After droping the missing values, the number of rows are `1228776 `and the number of columns are `20`.
# - After dropping the duplicates, the number of rows are `1228776` and the number of columns are `20`.
# - Check the data distribution of each numerical columns.
# - Average user rating of apps: `1.7890`.
# - Most reviewed app: `YouTube`:` Watch,` `Listen`, `Stream`.
# - Average size of apps (in bytes): `75064153`.
# - Number of free apps: `1126288`.
# - Number of paid apps: `102488`.
# - Top 5 developers by number of apps:
#     - ChowNow                   `3966`
#     - Touch2Success             `1649`
#     - Alexander Velimirovic     `1506`
#     - MINDBODY, Incorporated    `1247`
#     - Phorest                   `1131`
# - Most recent release date: `2021-10-14`.
# - Average price of paid apps: `6.04`.
# - Most common required iOS version: `11.0`
